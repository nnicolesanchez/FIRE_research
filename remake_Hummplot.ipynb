# %%
import matplotlib.pyplot as plt
from astropy.table import Table
import pandas

dat = Table.read('ray_rho_0032_0401.fits', format='fits')
df  = dat.to_pandas()
 
#df.wavelength # in angstroms
#df.flux       # relative flux 
#df.tau        # ???

# %%
fig = plt.figure(figsize=(15, 5))
ax1 = fig.add_subplot(111)
ax1.plot(df.wavelength,df.flux,color='Salmon')
ax1.set_title('Remake of Hummels Plot')
ax1.set_xlabel(r'Wavelength [$\AA$]')
ax1.set_ylabel('Relative Flux')
ax1.set_ylim(1150,1450)
ax1.set_ylim(0,2.5)
plt.show()

# %% [markdown]
# Below: Cameron Hummel's Flux($\lambda$)

# %% [markdown]
# <img src="./ray_rho_0032_0401.png">
